# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
tabla_1 = pd.read_json("../input/pasos.json", encoding= 'UTF-8')
print(str(len(tabla_1)) + ' registros')
# Out:
# 252 registros

# %%
#Corrijo datos erróneos.

tabla_1[tabla_1.province=='AEROPUERTO INTERNACIONAL PILOTO CIVIL NORBERTO FERNANDEZ']='Rio Gallegos'
tabla_1[tabla_1.name=='AERO RIO GALLEGOS']='AEROPUERTO INTERNACIONAL PILOTO CIVIL NORBERTO FERNANDEZ'

# %%
tabla_1.groupby('province').count().sort_values('location', ascending=False).plot.bar( y='location')
#tabla_1.groupby('province').count().sort('location').plot.bar( y='location')
